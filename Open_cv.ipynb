# %% [markdown]
# <a href="https://colab.research.google.com/github/zakir0741/OPEN_CV-examples-in-image-recognition/blob/main/Open_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-828c9f79-949b-404b-9328-cc2b09f85e17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-828c9f79-949b-404b-9328-cc2b09f85e17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]
image = cv2.imread(filename)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=331x455>

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=331x455>

# %%
resized = cv2.resize(image, (100, 100))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
resized = cv2.resize(gray, (100, 100))
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=100x100>

# %%
annotated = image.copy()
cv2.rectangle(annotated, (50,50),(250,250),(0,255,0), 3)
cv2.putText(annotated, 'My Box', (60, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0),2)
cv2_imshow(annotated)
# Out:
# <PIL.Image.Image image mode=RGB size=331x455>

# %% [markdown]
# DATA AUGMENTATION

# %%
cv2.imwrite('output_image.jpg',annotated)
print("Image saved as output_image.jpg")
# Out:
# Image saved as output_image.jpg

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
uploaded = files.upload()
filename = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-a3646b4b-5074-4338-bdfc-af10bd307ebe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3646b4b-5074-4338-bdfc-af10bd307ebe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = load_img(filename, target_size=(224,224))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.5, 1.5]
)
i = 0
for batch in datagen.flow(img_array, batch_size=1):
  plt.figure(figsize=(2,2))
  plt.imshow(batch[0].astype('uint8'))
  plt.axis('off')
  i += 1
  if i > 5:
    break
